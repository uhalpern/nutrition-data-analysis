# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# !pip install import_ipynb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import import_ipynb

# %%
from classification import predict_food_label
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 from classification import predict_food_label
#
# ImportError: cannot import name 'predict_food_label' from 'classification' (unknown location)

# %%
c.predic

# %%
data = pd.read_csv("nutrition_with_category.csv")

# %%
data['product'] = joined_food_list = [' '.join(food.split(', ')) for food in data['name']]
data.insert(2, 'product', data.pop('product'))
data.head()
# Out:
#    Unnamed: 0           category         product             name  \
# 0           0             Grains      Cornstarch       Cornstarch
# 1           1  Legumes and seeds     Nuts pecans     Nuts, pecans
# 2           2         Vegetables    Eggplant raw    Eggplant, raw
# 3           3             Grains   Teff uncooked   Teff, uncooked
# 4           4             Fruits  Sherbet orange  Sherbet, orange
#
#   serving_size  calories total_fat saturated_fat cholesterol    sodium  ...  \
# 0        100 g       381      0.1g           NaN           0   9.00 mg  ...
# 1        100 g       691       72g          6.2g           0   0.00 mg  ...
# 2        100 g        25      0.2g           NaN           0   2.00 mg  ...
# 3        100 g       367      2.4g          0.4g           0  12.00 mg  ...
# 4        100 g       144        2g          1.2g         1mg  46.00 mg  ...
#
#        fat saturated_fatty_acids monounsaturated_fatty_acids  \
# ...

# %%
data['natural_form'] = data['product'].apply(predict_food_label)
data.insert(4, 'natural_form', data.pop('natural_form'))
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 data['natural_form'] = data['product'].apply(predict_food_label)
#       2 data.insert(4, 'natural_form', data.pop('natural_form'))
#       3 data.head()
#
# NameError: name 'predict_food_label' is not defined

# %%
with open('data.txt', 'w') as file:

    for value in data['product']:
        file.write(f"{value.lower()}\n")
